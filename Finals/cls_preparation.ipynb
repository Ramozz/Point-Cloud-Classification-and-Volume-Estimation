# %%
# Train split
# 10 divisions

from pyntcloud import PyntCloud
import numpy as np

train_clouds = []
train_labels = [] 

#divides all the points for the furthest distance
def SphereNormalization():
    points = train_clouds
    centroid = np.mean(points, axis=0)
    points -= centroid
    furthest_distance = np.max(np.sqrt(np.Esum(abs(points)**2,axis=-1)))
    points /= furthest_distance
    return points

#load train files
def Import_Train_PCD():
# reads the point cloud to a np.array list
    
    #Spheres
    for number in range(1,1815): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(0)
        
    for number in range(2017,3831): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(1)
         
    #Parallelepipeds
    for number in range(4033,5847): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(2)
        
    for number in range(6049,7863): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(3)
        
    #Cubes
    for number in range(8065,9879): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(4)
        
    for number in range(10081, 11895): #adjust according to the samples generated 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(4)
        
    #Cylinders
    for number in range(12097,13911): #adjust according to the samples generated 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(5)
        
    for number in range(14113,15297): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(5)
        
    #Pyramids 
    for number in range(16129,17943): #adjust according to the samples generated 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(6)
        
    for number in range(18145,19959): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(6)
        
    print("Train data loaded !")

Import_Train_PCD()
#print(len(train_clouds[0])) #1a point cloud
train_clouds = SphereNormalization()
#print(train_clouds[0]) #1a point cloud

# %%
# Train split
# 20 divisions

from pyntcloud import PyntCloud
import numpy as np

train_clouds = []
train_labels = [] 

def SphereNormalization():
    points = train_clouds
    centroid = np.mean(points, axis=0)
    points -= centroid
    furthest_distance = np.max(np.sqrt(np.sum(abs(points)**2,axis=-1)))
    points /= furthest_distance
    return points

#load train files
def Import_Train_PCD():
# reads the point cloud to a np.array list

    #Spheres
    for number in range(1,164): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(0)
        
    for number in range(234,399): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(0)
         
    #Parallelepipeds
    for number in range(469,632): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(1)
        
    for number in range(702,867): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(1)
        
    #Cubes
    for number in range(936,1100): #adjust according to the samples generated 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(2)
        
    for number in range(1170, 1335): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(2)
        
    #Cylinders
    for number in range(1404,1568): #adjust according to the samples generated 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(3)
        
    for number in range(1638,1803): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(3)
        
    #Pyramids 
    for number in range(1872,2036): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(4)
        
    for number in range(2106,2271): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(4)
        
    #Spheres
    for number in range(2340,2504): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(4)
        
    for number in range(2574,2739): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(4)
         
    #Parallelepipeds
    for number in range(2808,2972): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(5)
        
    for number in range(3042,3207): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(5)
        
    #Cubes
    for number in range(3276,3440): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(5)
        
    for number in range(3510, 3675): #adjust according to the samples generated 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(5)
        
    #Cylinders
    for number in range(3744,3908): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(6)
        
    for number in range(3978,4143): #adjust according to the samples generated 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(6)
        
    #Pyramids 
    for number in range(4212,4376): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(6)
        
    for number in range(4446,4611): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        train_clouds.append(cloud)
        train_labels.append(6)
        
    print("Train data loaded !")

Import_Train_PCD()
#print(train_clouds[0]) #1a point cloud
train_clouds = SphereNormalization()
#print(train_clouds[0]) #1a point cloud
# Out:
# Train data loaded !
# [[ 124.07734 -458.37128  978.69946]
#  [ 130.04509 -475.9142  1027.746  ]
#  [ 130.07513 -471.51447 1029.9435 ]
#  ...
#  [-246.54721 -451.53098 1069.4357 ]
#  [-246.58046 -446.87494 1071.4902 ]
#  [-246.61058 -442.20676 1073.5168 ]]
# [[-0.09103761 -0.00971623 -0.06670334]
#  [-0.08286973 -0.01944134 -0.02568189]
#  [-0.08050961 -0.01270928 -0.02455687]
#  ...
#  [-0.171158   -0.13167724  0.45301834]
#  [-0.17098497 -0.12888196  0.45411983]
#  [-0.1709343  -0.12510638  0.45579916]]

# %%
# Writing train hdf5 

import h5py

data_file = h5py.File('Dataset/Train/file1.h5', 'w')
data_file.create_dataset('data', data=train_clouds ,compression='gzip', compression_opts=4, dtype='float32')
data_file.create_dataset('label', data=train_labels ,compression='gzip', compression_opts=1, dtype='float32')
data_file.close()

# %%
# Test split
# 10 divisions

test_clouds = []
test_labels = []
 
# sphere normalization for test clouds
def TSphereNormalization():
    points = test_clouds
    centroid = np.mean(points, axis=0)
    points -= centroid
    furthest_distance = np.max(np.sqrt(np.sum(abs(points)**2,axis=-1)))
    points /= furthest_distance
    return points

# Load test files
def Import_Test_PCD():

    #Spheres
    for number in range(1815,2017): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(0)
        
    for number in range(3831,4033): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(1)
        
    #Parallelepipeds
    for number in range(5847,6049): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(2)
        
    for number in range(7863,8065): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(3)
        
    #Cubes
    for number in range(9879,10081): #adjust according to the samples generated 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(4)
        
    for number in range(11895, 12097): #adjust according to the samples generated 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(4)
        
    #Cylinders
    for number in range(13911,  14113): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(5)
        
    for number in range(15927,16129): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(5)
        
    #Pyramids
    for number in range(17943,18145): #adjust according to the samples generated 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(6)
        
    for number in range(19959,20161): #adjust according to the samples generated 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(6)
        
    print("Test data loaded !")

    
Import_Test_PCD()
#print(test_clouds[456]) #1a point cloud
test_clouds = TSphereNormalization()
#print(test_clouds[456]) #1a point cloud
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-83cc6d8eb17b> in <module>
#      94     #print(clean_dataset[0][:340])
#      95
# ---> 96 Import_Test_PCD()
#      97
#      98 print(test_clouds[456]) #1a point cloud
#
# <ipython-input-4-83cc6d8eb17b> in Import_Test_PCD()
#      33     for number in range(5847,6049): #ajustar para o numero total de samples
#      34         file = "Dataset/Generated/cloud{}.pcd".format(number)
# ---> 35         data = PyntCloud.from_file(file)
#      36         cloud = data.xyz
#      37         test_clouds.append(cloud)
#
# C:\Anaconda\lib\site-packages\pyntcloud\core_class.py in from_file(cls, filename, **kwargs)
#     128                 "Unsupported file format; supported formats are: {}".format(list(FROM)))
#     129         else:
# --> 130             return cls(**FROM[ext](filename, **kwargs))
#     131
# ...

# %%
# Test split
# 20 divisions

from pyntcloud import PyntCloud
import numpy as np

test_clouds = []
test_labels = []
 
def TSphereNormalization():
    points = test_clouds
    centroid = np.mean(points, axis=0)
    points -= centroid
    furthest_distance = np.max(np.sqrt(np.sum(abs(points)**2,axis=-1)))
    points /= furthest_distance
    return points
        
def Import_Test_PCD():
# le pointcloud inteira do pcd para dentro de uma lista de np.array
#Para- sphere - cube- cy- pir
    #load train files
    # Two for for each directory because there are 2 diff objects
    #Spheres
    for number in range(164,234): #ajustar para o numero total de samples 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(0)
        
    for number in range(399,469): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(0)
        
    #Parallelepipeds
    for number in range(632,702): #adjust according to the samples generated 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(1)
        
    for number in range(867,936): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(1)
        
    #Cubes
    for number in range(1100,1170): #adjust according to the samples generated 
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(2)
        
    for number in range(1335, 1404): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(2)
        
    #Cylinders
    for number in range(1568,  1638): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(3)
        
    for number in range(1803,1872): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(3)
        
    #Pyramids
    for number in range(2036,2106): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(4)
        
    for number in range(2271,2340): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(4)
        
    for number in range(2504,2574): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(4)
        
    for number in range(2739,2808): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(4)
        
    #Parallelepipeds
    for number in range(2972,3042): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(5)
        
    for number in range(3207,3276): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(5)
        
    #Cubes
    for number in range(3440,3510): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(5)
        
    for number in range(3675, 3744): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(5)
        
    #Cylinders
    for number in range(3908, 3978): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(6)
        
    for number in range(4143,4212): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(6)
        
    #Pyramids
    for number in range(4376,4446): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(6)
        
    for number in range(4611,4681): #adjust according to the samples generated
        file = "Dataset/Generated/cloud{}.pcd".format(number)
        data = PyntCloud.from_file(file)
        cloud = data.xyz
        test_clouds.append(cloud)
        test_labels.append(6)
        
    print("Test data loaded !")
    
Import_Test_PCD()

#print(test_clouds[456]) #1a point cloud
test_clouds = TSphereNormalization()
#print(test_clouds[456]) #1a point cloud
# Out:
# Test data loaded !
# [[ 296.9649   -416.87186  1065.4451  ]
#  [ 298.15704  -460.0254   1076.0931  ]
#  [ 292.0851   -422.1648   1065.1323  ]
#  ...
#  [  50.978138 -716.3501    845.6215  ]
#  [  51.026733 -713.18567   849.43414 ]
#  [  51.07463  -709.9935    853.2212  ]]
# [[ 0.0503501   0.02282499  0.00475959]
#  [ 0.05438352 -0.00857148  0.01337085]
#  [ 0.05136497  0.03093928  0.00303895]
#  ...
#  [ 0.08467084 -0.36256728  0.2788766 ]
#  [ 0.08482192 -0.362939    0.2815521 ]
#  [ 0.08490624 -0.3635877   0.28430855]]

# %%
#Write test hdf5

data_file = h5py.File('Dataset/Test/file2.h5', 'w')
data_file.create_dataset('data', data=test_clouds ,compression='gzip', compression_opts=4, dtype='float32')
data_file.create_dataset('label', data=test_labels ,compression='gzip', compression_opts=1, dtype='float32')
data_file.close()

# %%
#Reading the hdf5 generated
import h5py
filename = 'Dataset/Train/file1.h5'
f = h5py.File(filename, 'r')

# List all groups
print("Keys: %s" % f.keys())
a_group_key = list(f.keys())[0] # key data


# Get the data of 1 of the key data, which corresponds to all the points
data = list(f[a_group_key])

# just one point cloud
print(data[0])
# Out:
# Keys: <KeysViewHDF5 ['data', 'label']>

# %%
#visualization of the stored values

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# select one test data to visualize
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
v_points = np.array(train_clouds[301]) #point cloud selected
v_points = np.squeeze(v_points)

for i in range(v_points.shape[0]):  
    xs = v_points[i,0]
    ys = v_points[i,1]
    zs = v_points[i,2]
    ax.scatter(xs, ys, zs)
     

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.show()
